# %%
import pandas as pd
import matplotlib.pyplot as plt


file1 = 'injection_mechFrac_out_3_frac.csv' 



data1 = pd.read_csv(file1)


time1 = data1.iloc[1:222, 0]  # Rows from 1 to 2635
J_1 = data1['p1_lagged_perm'].iloc[1:222]

# %%
plt.figure(figsize=(12, 6))
plt.plot(time1/(3600), J_1, label='5 kg/s', color='black', linestyle='--', linewidth=2.5)

plt.rcParams.update({'font.size': 16})

plt.xlabel('Time (hours)')
plt.ylabel('Permeability ($m^{2}$)')
plt.title('Change in Permeability with Time')
plt.grid(True)
# plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(time1/(3600*24), T1_1, label='5 kg/s', color='blue', linestyle='--')
plt.plot(time1/(3600*24), T1_2, label='10 kg/s', color='red', linestyle='--')
plt.plot(time1/(3600*24), T1_3, label='15 kg/s', color='green', linestyle='--')
plt.plot(time1/(3600*24), T1_4, label='20 kg/s', color='orange', linestyle='--')
plt.plot(time1/(3600*24), T1_5, label='30 kg/s', color='black', linestyle='--')

# plt.plot(time3, T2_1_5m, label='T1', color='black')
# plt.plot(time3, T2_2_5m, label='T3', color='yellow')
plt.xlabel('Time (days)')
plt.ylabel('Temperature (k)')
plt.title('Temperature vs. Time(Zone1_2_3)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(time1/(3600*24), T3_1, label='5 kg/s', color='blue', linestyle='--')
plt.plot(time1/(3600*24), T3_2, label='10 kg/s', color='red', linestyle='--')
plt.plot(time1/(3600*24), T3_3, label='15 kg/s', color='green', linestyle='--')
plt.plot(time1/(3600*24), T3_4, label='20 kg/s', color='orange', linestyle='--')
plt.plot(time1/(3600*24), T3_5, label='30 kg/s', color='black', linestyle='--')


plt.xlabel('Time (days)')
plt.ylabel('Temperature (K)')
plt.title('Temperature of rock at production point')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(time1/(3600*24), P3_1, label='5 kg/s', color='blue', linestyle='-.')
plt.plot(time1/(3600*24), P3_2, label='10 kg/s', color='red', linestyle='-.')
plt.plot(time1/(3600*24), P3_3, label='15 kg/s', color='green', linestyle='-.')
plt.plot(time1/(3600*24), P3_4, label='20 kg/s', color='orange', linestyle='-.')
plt.plot(time1/(3600*24), P3_5, label='30 kg/s', color='black', linestyle='-.')


plt.xlabel('Time (days)')
plt.ylabel('Pressure (Pa)')
plt.title('Pressure at production point')
plt.grid(True)
plt.legend()
plt.show()
